# %% [markdown]
# <center> <h1> Diagnose Latent Cytomegalovirus Using CyTOF Data and Deep Learning <h1> </center>
#
# <center>Zicheng Hu, Ph.D.</center>
# <center>Research Scientist</center>
# <center>ImmPort Team</center>
# <center>The Unversity of California, San Francisco</center>
#
# ![alt text](Data/header.png)

# %% [markdown]
# ### Introduction
# A deep neural network (a.k.a. deep learning) is an artificial neural network with multiple layers between the input and output layers. It was proven to be highly effective for a variety of predictive tasks. In health care, deep learning is quickly gaining popularity and has been implemented for applications such as image-based diagnosis and personalized drug recommendations. In this tutorial, we will build a tailored deep-learning model for CyTOF data to diagnosis latent Cytomegalovirus infection using Keras and TensorFlow.

# %% [markdown]
# ### Step 1: Import Functions
# Before we start, we first import functions that we will use in this tutorial from different libraries.

# %%
##### Step 1: import functions #####
from keras.layers import Dense, Flatten, BatchNormalization, Activation, Conv2D, AveragePooling2D, Input
from keras.models import load_model, Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K
import pickle
import pandas as pd
import numpy as np
from numpy.random import seed; seed(111)
import random
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import set_random_seed; set_random_seed(111)
from sklearn.metrics import roc_curve, auc
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz, DecisionTreeRegressor
from scipy.stats import ttest_ind
from IPython.display import Image  
import pydotplus

# %% [markdown]
# ### Step 2: Load data
# We then load the data, which are stored in the "allData.obj" file. For the convenience of this tutorial, the data are downloaded from the ImmPort database and are already preprocessed. The data includes three parts, meta-data, CyTOF data, and marker names.
#
# * The **meta-data** contains the sample level information, including the study accession number for each sample and the ground truth of CMV infection. It is stored as a pandas data frame.
# * The **CyTOF data** contains the single-cell profile of 27 markers. They are arcsinh transformed data from raw FCS files. It is stored in a three-dimensional numpy array. The dimension of the numpy array is 472 samples x 10000 cells x 27 markers.
# * The **marker names** contain the name of the markers.

# %%
##### Step 2: load data #####

#Download data
tutorial_files = ! ls Data
if "allData.obj" not in tutorial_files:
    print("Downloading Data:")
    ! wget https://storage.googleapis.com/focis-tutoria-data/allData.obj -P ./Data
        
#load data
allData = pickle.load( open( "Data/allData.obj", "rb" ) )
metaData = allData["metaData"]
cytoData = allData["cytoData"]
markerNames = allData["markerNames"]

# inspect the data
print("\nFirst 5 rows of metaData: ")
print(metaData.head(),"\n")

print("Dimensions of cytoData: ",cytoData.shape,"\n")
print("Names of the 27 makers: \n",markerNames.values)
# Out:
# First 5 rows of metaData:
#                                                  name study_accession  CMV_Ab
# 0   011514-Mike-Study 21-2011-plate 1-2100101_cell...          SDY113    True
# 1   011514-Mike-Study 21-2011-plate 1-2100201_cell...          SDY113    True
# 3   011514-Mike-Study 21-2011-plate 1-2100501_cell...          SDY113    True
# 6   011514-Mike-Study 21-2011-plate 1-2100901_cell...          SDY113   False
# 19  011514-Mike-Study 21-2011-plate 1-2102501_cell...          SDY113   False
#
# Dimensions of cytoData:  (472, 10000, 27, 1)
#
# Names of the 27 makers:
#  ['VIABILITY' 'TCRGD' 'IGD' 'HLADR' 'DNA2' 'DNA1' 'CELL_LENGTH' 'CD94'
#  'CD85J' 'CD8' 'CD56' 'CD45RA' 'CD4' 'CD38' 'CD33' 'CD3' 'CD28' 'CD27'
#  'CD25' 'CD24' 'CD20' 'CD19' 'CD161' 'CD16' 'CD14' 'CD127' 'CCR7']

# %% [markdown]
# ### Step 3: Split data into training, validation and testing sets
# Now, lets split the data into training, validation, and testing sets. The training data is used to train the deep learning model. The validation dataset is used to select the best parameters for the model and to avoid overfitting. The test dataset is used to evaluate the performance of the final model.
#
# The CyTOF dataset contains samples from 9 studies available on ImmPort. We will use samples from the study SDY515 as a validation set, samples from the study SDY519 as a testing set, and the rest of the samples as a training set.

# %%
##### Step 3: split train, validation and test######
y = metaData.CMV_Ab.values
x = cytoData

train_id = (metaData.study_accession.isin(["SDY515","SDY519"])==False)
valid_id = metaData.study_accession=="SDY515"
test_id = metaData.study_accession =="SDY519"

x_train = x[train_id]; y_train = y[train_id]
x_valid = x[valid_id]; y_valid = y[valid_id]
x_test = x[test_id]; y_test = y[test_id]

# %% [markdown]
# ### Step 4: Define the deep learning model
# We will use a customized convolution neural network (CNN) to analyze the CyTOF data. For each sample, the CyTOF data is a matrix with rows as cells and columns as markers. It is crucial to notice that the order of cells is arbitrary in CyTOF data. For example, both matrix 1 and matrix 2 profiles the same sample in Figure 1A, even though they have different orders of rows.
#
# ![alt text](Data/Figure1.png)
#
#
# Based on the characteristics of the CyTOF data, we design a CNN model to predict sample-level information using the raw CyTOF data as input. The model contains six layers: input layer, first and second convolution layer, pooling layer, dense layer, and output layer.
#
# * The **input layer** receives the CyTOF data matrix.
#
# * The **first convolution layer** uses three filters to scan each row of the CyTOF data. This layer extracts relevant information from the cell marker profile of each cell.
#
# * The **second convolution layer** uses three filters to scan each row of the first layer's output. Each filter combines information from the first layer for each cell.
#
# * The **pooling layers** averages the outputs of the second convolution layer. The purpose is to aggregate the cell level information into sample-level information.
#
# * The **dense layer** further extracts information from the pooling layer.
#
# * The **output layer** uses logistic regression to report the probability of CMV infection for each sample.

# %%
##### Step 4: define model #####

# input
model_input = Input(shape=x_train[0].shape)

# first convolution layer
model_output = Conv2D(3, kernel_size=(1, x_train.shape[2]),
                 activation=None)(model_input)
model_output = BatchNormalization()(model_output)
model_output = Activation("relu")(model_output)

# sceond convolution layer
model_output = Conv2D(3, (1, 1), activation=None)(model_output)
model_output = BatchNormalization()(model_output)
model_output = Activation("relu")(model_output)

# pooling layer
model_output = AveragePooling2D(pool_size=(x_train.shape[1], 1))(model_output)
model_output = Flatten()(model_output)

# Dense layer
model_output = Dense(3, activation=None)(model_output)
model_output = BatchNormalization()(model_output)
model_output = Activation("relu")(model_output)

# output layer
model_output = Dense(1, activation=None)(model_output)
model_output = BatchNormalization()(model_output)
model_output = Activation("sigmoid")(model_output)
# Out:
# WARNING:tensorflow:From /Users/zichenghu/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Step 5: Fit the model
# In this step, we will use the training data to fit the model. We will use the Adam algorithm, which is an extension of the gradient descent method to train our model. Adam algorithm will search the model space step by step (epochs) until the optimal model is identified. At each step, we will use validation data to evaluate the performance of the model. The best model will be saved.
#
# To save time, we will only run the first 150 epochs as a demonstration. We will load the final model from a save file (Final_weights.hdf5) for the following analysis steps.

# %%
##### Step 5: Fit model #####

# specify input and output
model = Model(inputs=[model_input],
              outputs=model_output)

# define loss function and optimizer
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.0001),
              metrics=['accuracy'])

# save the best performing model using validation result
checkpointer = ModelCheckpoint(filepath='Result/saved_weights.hdf5', 
                               monitor='val_loss', verbose=0, 
                               save_best_only=True)

# model training
model.fit([x_train], y_train,
          batch_size=60,
          epochs=500, # increase the epochs to 500 to fully train the model
          verbose=1,
          callbacks=[checkpointer],
          validation_data=([x_valid], y_valid))
# Out:
# WARNING:tensorflow:From /Users/zichenghu/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 333 samples, validate on 79 samples
# Epoch 1/500
# 333/333 [==============================] - 12s 35ms/step - loss: 0.8607 - acc: 0.4595 - val_loss: 0.7309 - val_acc: 0.5443
# Epoch 2/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.8600 - acc: 0.4505 - val_loss: 0.7331 - val_acc: 0.5316
# Epoch 3/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.8595 - acc: 0.4685 - val_loss: 0.7327 - val_acc: 0.5443
# Epoch 4/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.8469 - acc: 0.4835 - val_loss: 0.7341 - val_acc: 0.5316
# Epoch 5/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.8484 - acc: 0.4715 - val_loss: 0.7344 - val_acc: 0.5316
# Epoch 6/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.8520 - acc: 0.4655 - val_loss: 0.7367 - val_acc: 0.5190
# Epoch 7/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.8294 - acc: 0.4925 - val_loss: 0.7391 - val_acc: 0.5063
# Epoch 8/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.8392 - acc: 0.4895 - val_loss: 0.7399 - val_acc: 0.5190
# Epoch 9/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.8523 - acc: 0.4925 - val_loss: 0.7416 - val_acc: 0.5190
# Epoch 10/500
# 333/333 [==============================] - 8s 26ms/step - loss: 0.8485 - acc: 0.4715 - val_loss: 0.7439 - val_acc: 0.5190
# Epoch 11/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.8392 - acc: 0.4745 - val_loss: 0.7460 - val_acc: 0.5316
# Epoch 12/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.8430 - acc: 0.4835 - val_loss: 0.7485 - val_acc: 0.5190
# Epoch 13/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.8382 - acc: 0.5045 - val_loss: 0.7507 - val_acc: 0.5190
# Epoch 14/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.8386 - acc: 0.4865 - val_loss: 0.7519 - val_acc: 0.5190
# Epoch 15/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.8340 - acc: 0.4895 - val_loss: 0.7527 - val_acc: 0.5190
# Epoch 16/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.8356 - acc: 0.4895 - val_loss: 0.7536 - val_acc: 0.5190
# Epoch 17/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.8341 - acc: 0.4805 - val_loss: 0.7541 - val_acc: 0.5190
# Epoch 18/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.8198 - acc: 0.4925 - val_loss: 0.7552 - val_acc: 0.5063
# Epoch 19/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.8301 - acc: 0.4835 - val_loss: 0.7569 - val_acc: 0.4937
# Epoch 20/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.8308 - acc: 0.4835 - val_loss: 0.7590 - val_acc: 0.4937
# Epoch 21/500
# 333/333 [==============================] - 11s 33ms/step - loss: 0.8249 - acc: 0.4835 - val_loss: 0.7610 - val_acc: 0.4937
# Epoch 22/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.8214 - acc: 0.4985 - val_loss: 0.7633 - val_acc: 0.5063
# Epoch 23/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.8234 - acc: 0.4805 - val_loss: 0.7657 - val_acc: 0.4810
# Epoch 24/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.8238 - acc: 0.4895 - val_loss: 0.7690 - val_acc: 0.4810
# Epoch 25/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.8152 - acc: 0.5075 - val_loss: 0.7713 - val_acc: 0.4684
# Epoch 26/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.8095 - acc: 0.4925 - val_loss: 0.7727 - val_acc: 0.4684
# Epoch 27/500
# 333/333 [==============================] - 9s 29ms/step - loss: 0.8078 - acc: 0.5135 - val_loss: 0.7751 - val_acc: 0.4557
# Epoch 28/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.8202 - acc: 0.4805 - val_loss: 0.7765 - val_acc: 0.4557
# Epoch 29/500
# 333/333 [==============================] - 11s 33ms/step - loss: 0.8066 - acc: 0.5165 - val_loss: 0.7789 - val_acc: 0.4557
# Epoch 30/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.8087 - acc: 0.4895 - val_loss: 0.7817 - val_acc: 0.4557
# Epoch 31/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.8059 - acc: 0.5045 - val_loss: 0.7859 - val_acc: 0.4557
# Epoch 32/500
# 333/333 [==============================] - 11s 32ms/step - loss: 0.7979 - acc: 0.5315 - val_loss: 0.7891 - val_acc: 0.4430
# Epoch 33/500
# 333/333 [==============================] - 11s 33ms/step - loss: 0.7881 - acc: 0.5255 - val_loss: 0.7925 - val_acc: 0.4557
# Epoch 34/500
# 333/333 [==============================] - 11s 32ms/step - loss: 0.7973 - acc: 0.5255 - val_loss: 0.7964 - val_acc: 0.4557
# Epoch 35/500
# 333/333 [==============================] - 11s 32ms/step - loss: 0.8018 - acc: 0.5255 - val_loss: 0.8012 - val_acc: 0.4557
# Epoch 36/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.8037 - acc: 0.5315 - val_loss: 0.8061 - val_acc: 0.4430
# Epoch 37/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7920 - acc: 0.5285 - val_loss: 0.8106 - val_acc: 0.4430
# Epoch 38/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.8114 - acc: 0.4955 - val_loss: 0.8175 - val_acc: 0.4304
# Epoch 39/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.7930 - acc: 0.5255 - val_loss: 0.8241 - val_acc: 0.4430
# Epoch 40/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7965 - acc: 0.5165 - val_loss: 0.8286 - val_acc: 0.4304
# Epoch 41/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.7912 - acc: 0.5345 - val_loss: 0.8336 - val_acc: 0.4557
# Epoch 42/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7858 - acc: 0.5225 - val_loss: 0.8367 - val_acc: 0.4684
# Epoch 43/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7967 - acc: 0.5045 - val_loss: 0.8409 - val_acc: 0.4684
# Epoch 44/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7790 - acc: 0.5435 - val_loss: 0.8458 - val_acc: 0.4557
# Epoch 45/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.7816 - acc: 0.5195 - val_loss: 0.8501 - val_acc: 0.4557
# Epoch 46/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.7823 - acc: 0.5195 - val_loss: 0.8548 - val_acc: 0.4557
# Epoch 47/500
# 333/333 [==============================] - 11s 33ms/step - loss: 0.7798 - acc: 0.5285 - val_loss: 0.8607 - val_acc: 0.4810
# Epoch 48/500
# 333/333 [==============================] - 9s 29ms/step - loss: 0.7769 - acc: 0.5255 - val_loss: 0.8668 - val_acc: 0.4684
# Epoch 49/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.7661 - acc: 0.5285 - val_loss: 0.8722 - val_acc: 0.4684
# Epoch 50/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7699 - acc: 0.5435 - val_loss: 0.8786 - val_acc: 0.4684
# Epoch 51/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7714 - acc: 0.5285 - val_loss: 0.8869 - val_acc: 0.4810
# Epoch 52/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7716 - acc: 0.5465 - val_loss: 0.8924 - val_acc: 0.4684
# Epoch 53/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7601 - acc: 0.5556 - val_loss: 0.8978 - val_acc: 0.4684
# Epoch 54/500
# 333/333 [==============================] - 11s 32ms/step - loss: 0.7627 - acc: 0.5285 - val_loss: 0.9045 - val_acc: 0.4810
# Epoch 55/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7468 - acc: 0.5435 - val_loss: 0.9098 - val_acc: 0.4684
# Epoch 56/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7622 - acc: 0.5195 - val_loss: 0.9163 - val_acc: 0.4810
# Epoch 57/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7597 - acc: 0.5495 - val_loss: 0.9222 - val_acc: 0.4684
# Epoch 58/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7568 - acc: 0.5465 - val_loss: 0.9333 - val_acc: 0.4810
# Epoch 59/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7461 - acc: 0.5646 - val_loss: 0.9411 - val_acc: 0.4937
# Epoch 60/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.7477 - acc: 0.5616 - val_loss: 0.9480 - val_acc: 0.4810
# Epoch 61/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.7477 - acc: 0.5255 - val_loss: 0.9555 - val_acc: 0.4684
# Epoch 62/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7403 - acc: 0.5526 - val_loss: 0.9639 - val_acc: 0.4557
# Epoch 63/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7405 - acc: 0.5616 - val_loss: 0.9720 - val_acc: 0.4430
# Epoch 64/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7389 - acc: 0.5586 - val_loss: 0.9799 - val_acc: 0.4430
# Epoch 65/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7299 - acc: 0.5706 - val_loss: 0.9888 - val_acc: 0.4430
# Epoch 66/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7340 - acc: 0.5465 - val_loss: 1.0003 - val_acc: 0.4557
# Epoch 67/500
# 333/333 [==============================] - 11s 32ms/step - loss: 0.7363 - acc: 0.5556 - val_loss: 1.0054 - val_acc: 0.4304
# Epoch 68/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7298 - acc: 0.5676 - val_loss: 1.0090 - val_acc: 0.4430
# Epoch 69/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7309 - acc: 0.5465 - val_loss: 1.0113 - val_acc: 0.4430
# Epoch 70/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7300 - acc: 0.5556 - val_loss: 1.0176 - val_acc: 0.4304
# Epoch 71/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7235 - acc: 0.5495 - val_loss: 1.0224 - val_acc: 0.4304
# Epoch 72/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7323 - acc: 0.5736 - val_loss: 1.0262 - val_acc: 0.4304
# Epoch 73/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.7196 - acc: 0.5676 - val_loss: 1.0308 - val_acc: 0.4304
# Epoch 74/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.7167 - acc: 0.5676 - val_loss: 1.0362 - val_acc: 0.4304
# Epoch 75/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.7236 - acc: 0.5736 - val_loss: 1.0435 - val_acc: 0.4304
# Epoch 76/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7028 - acc: 0.5796 - val_loss: 1.0476 - val_acc: 0.4430
# Epoch 77/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7198 - acc: 0.5886 - val_loss: 1.0543 - val_acc: 0.4304
# Epoch 78/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.7051 - acc: 0.5856 - val_loss: 1.0586 - val_acc: 0.4304
# Epoch 79/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7170 - acc: 0.5796 - val_loss: 1.0607 - val_acc: 0.4304
# Epoch 80/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7112 - acc: 0.5796 - val_loss: 1.0624 - val_acc: 0.4430
# Epoch 81/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.7158 - acc: 0.5796 - val_loss: 1.0655 - val_acc: 0.4430
# Epoch 82/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.7019 - acc: 0.5826 - val_loss: 1.0685 - val_acc: 0.4430
# Epoch 83/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.7037 - acc: 0.5886 - val_loss: 1.0713 - val_acc: 0.4430
# Epoch 84/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6995 - acc: 0.5916 - val_loss: 1.0741 - val_acc: 0.4304
# Epoch 85/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.7079 - acc: 0.5736 - val_loss: 1.0789 - val_acc: 0.4304
# Epoch 86/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6937 - acc: 0.6066 - val_loss: 1.0831 - val_acc: 0.4177
# Epoch 87/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.7079 - acc: 0.5706 - val_loss: 1.0831 - val_acc: 0.4304
# Epoch 88/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6905 - acc: 0.5976 - val_loss: 1.0803 - val_acc: 0.4430
# Epoch 89/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6975 - acc: 0.5826 - val_loss: 1.0771 - val_acc: 0.4430
# Epoch 90/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6900 - acc: 0.6066 - val_loss: 1.0763 - val_acc: 0.4430
# Epoch 91/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6925 - acc: 0.5976 - val_loss: 1.0734 - val_acc: 0.4304
# Epoch 92/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6914 - acc: 0.5736 - val_loss: 1.0722 - val_acc: 0.4304
# Epoch 93/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.6929 - acc: 0.5946 - val_loss: 1.0665 - val_acc: 0.4304
# Epoch 94/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.6884 - acc: 0.5826 - val_loss: 1.0642 - val_acc: 0.4304
# Epoch 95/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.6792 - acc: 0.6246 - val_loss: 1.0606 - val_acc: 0.4304
# Epoch 96/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.6869 - acc: 0.6066 - val_loss: 1.0572 - val_acc: 0.4304
# Epoch 97/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.6808 - acc: 0.5976 - val_loss: 1.0510 - val_acc: 0.4304
# Epoch 98/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.6777 - acc: 0.5916 - val_loss: 1.0487 - val_acc: 0.4304
# Epoch 99/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6747 - acc: 0.5736 - val_loss: 1.0472 - val_acc: 0.4304
# Epoch 100/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6765 - acc: 0.5976 - val_loss: 1.0445 - val_acc: 0.4304
# Epoch 101/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6763 - acc: 0.6036 - val_loss: 1.0429 - val_acc: 0.4304
# Epoch 102/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6645 - acc: 0.6126 - val_loss: 1.0443 - val_acc: 0.4304
# Epoch 103/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6862 - acc: 0.5916 - val_loss: 1.0439 - val_acc: 0.4304
# Epoch 104/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6730 - acc: 0.5916 - val_loss: 1.0407 - val_acc: 0.4304
# Epoch 105/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6727 - acc: 0.5946 - val_loss: 1.0379 - val_acc: 0.4304
# Epoch 106/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6643 - acc: 0.6066 - val_loss: 1.0380 - val_acc: 0.4304
# Epoch 107/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6661 - acc: 0.6126 - val_loss: 1.0302 - val_acc: 0.4304
# Epoch 108/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6636 - acc: 0.6246 - val_loss: 1.0250 - val_acc: 0.4304
# Epoch 109/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6808 - acc: 0.5976 - val_loss: 1.0223 - val_acc: 0.4304
# Epoch 110/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6638 - acc: 0.6186 - val_loss: 1.0176 - val_acc: 0.4304
# Epoch 111/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6609 - acc: 0.6336 - val_loss: 1.0109 - val_acc: 0.4051
# Epoch 112/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6619 - acc: 0.6336 - val_loss: 1.0065 - val_acc: 0.4051
# Epoch 113/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6539 - acc: 0.6036 - val_loss: 1.0022 - val_acc: 0.4051
# Epoch 114/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6597 - acc: 0.6186 - val_loss: 0.9995 - val_acc: 0.4177
# Epoch 115/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6491 - acc: 0.6186 - val_loss: 0.9986 - val_acc: 0.4177
# Epoch 116/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6603 - acc: 0.6276 - val_loss: 0.9944 - val_acc: 0.4177
# Epoch 117/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6559 - acc: 0.6486 - val_loss: 0.9880 - val_acc: 0.4304
# Epoch 118/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6580 - acc: 0.6126 - val_loss: 0.9831 - val_acc: 0.4304
# Epoch 119/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6527 - acc: 0.6096 - val_loss: 0.9773 - val_acc: 0.4304
# Epoch 120/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6480 - acc: 0.6216 - val_loss: 0.9734 - val_acc: 0.4304
# Epoch 121/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6439 - acc: 0.6246 - val_loss: 0.9701 - val_acc: 0.4304
# Epoch 122/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6427 - acc: 0.6276 - val_loss: 0.9619 - val_acc: 0.4304
# Epoch 123/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6464 - acc: 0.6306 - val_loss: 0.9534 - val_acc: 0.4177
# Epoch 124/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6487 - acc: 0.6186 - val_loss: 0.9442 - val_acc: 0.4177
# Epoch 125/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6472 - acc: 0.6156 - val_loss: 0.9375 - val_acc: 0.3924
# Epoch 126/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6483 - acc: 0.6126 - val_loss: 0.9299 - val_acc: 0.3924
# Epoch 127/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6470 - acc: 0.6216 - val_loss: 0.9257 - val_acc: 0.3797
# Epoch 128/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6343 - acc: 0.6306 - val_loss: 0.9249 - val_acc: 0.3797
# Epoch 129/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6356 - acc: 0.6517 - val_loss: 0.9246 - val_acc: 0.3797
# Epoch 130/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6468 - acc: 0.6517 - val_loss: 0.9225 - val_acc: 0.3797
# Epoch 131/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6348 - acc: 0.6186 - val_loss: 0.9189 - val_acc: 0.3797
# Epoch 132/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6315 - acc: 0.6246 - val_loss: 0.9144 - val_acc: 0.3924
# Epoch 133/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6270 - acc: 0.6396 - val_loss: 0.9094 - val_acc: 0.3924
# Epoch 134/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6492 - acc: 0.6156 - val_loss: 0.9075 - val_acc: 0.3924
# Epoch 135/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6368 - acc: 0.6396 - val_loss: 0.9033 - val_acc: 0.3924
# Epoch 136/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6321 - acc: 0.6396 - val_loss: 0.8983 - val_acc: 0.3924
# Epoch 137/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6410 - acc: 0.6336 - val_loss: 0.8916 - val_acc: 0.3924
# Epoch 138/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6252 - acc: 0.6667 - val_loss: 0.8874 - val_acc: 0.3924
# Epoch 139/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6301 - acc: 0.6486 - val_loss: 0.8847 - val_acc: 0.3924
# Epoch 140/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6165 - acc: 0.6727 - val_loss: 0.8806 - val_acc: 0.4051
# Epoch 141/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6314 - acc: 0.6426 - val_loss: 0.8763 - val_acc: 0.4177
# Epoch 142/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6260 - acc: 0.6547 - val_loss: 0.8737 - val_acc: 0.4177
# Epoch 143/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6340 - acc: 0.6276 - val_loss: 0.8702 - val_acc: 0.4051
# Epoch 144/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6263 - acc: 0.6517 - val_loss: 0.8672 - val_acc: 0.4051
# Epoch 145/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6192 - acc: 0.6637 - val_loss: 0.8632 - val_acc: 0.4051
# Epoch 146/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6180 - acc: 0.6486 - val_loss: 0.8631 - val_acc: 0.3924
# Epoch 147/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6168 - acc: 0.6486 - val_loss: 0.8621 - val_acc: 0.3924
# Epoch 148/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6130 - acc: 0.6697 - val_loss: 0.8596 - val_acc: 0.3924
# Epoch 149/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6118 - acc: 0.6577 - val_loss: 0.8583 - val_acc: 0.3924
# Epoch 150/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6074 - acc: 0.6637 - val_loss: 0.8538 - val_acc: 0.3924
# Epoch 151/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6169 - acc: 0.6787 - val_loss: 0.8509 - val_acc: 0.3924
# Epoch 152/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6158 - acc: 0.6577 - val_loss: 0.8507 - val_acc: 0.3924
# Epoch 153/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6017 - acc: 0.6607 - val_loss: 0.8466 - val_acc: 0.4304
# Epoch 154/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6105 - acc: 0.6877 - val_loss: 0.8429 - val_acc: 0.4304
# Epoch 155/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6171 - acc: 0.6577 - val_loss: 0.8401 - val_acc: 0.4430
# Epoch 156/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6128 - acc: 0.6577 - val_loss: 0.8385 - val_acc: 0.4430
# Epoch 157/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6151 - acc: 0.6547 - val_loss: 0.8370 - val_acc: 0.4430
# Epoch 158/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6293 - acc: 0.6336 - val_loss: 0.8361 - val_acc: 0.4430
# Epoch 159/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6048 - acc: 0.6517 - val_loss: 0.8363 - val_acc: 0.4430
# Epoch 160/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6157 - acc: 0.6637 - val_loss: 0.8344 - val_acc: 0.4430
# Epoch 161/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6115 - acc: 0.6517 - val_loss: 0.8352 - val_acc: 0.4430
# Epoch 162/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6118 - acc: 0.6607 - val_loss: 0.8350 - val_acc: 0.4430
# Epoch 163/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5991 - acc: 0.6757 - val_loss: 0.8340 - val_acc: 0.4430
# Epoch 164/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6124 - acc: 0.6697 - val_loss: 0.8338 - val_acc: 0.4430
# Epoch 165/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.6079 - acc: 0.6907 - val_loss: 0.8335 - val_acc: 0.4430
# Epoch 166/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.6035 - acc: 0.6607 - val_loss: 0.8328 - val_acc: 0.4430
# Epoch 167/500
# 333/333 [==============================] - 8s 26ms/step - loss: 0.6024 - acc: 0.6667 - val_loss: 0.8316 - val_acc: 0.4557
# Epoch 168/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5967 - acc: 0.6697 - val_loss: 0.8319 - val_acc: 0.4557
# Epoch 169/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5864 - acc: 0.6877 - val_loss: 0.8310 - val_acc: 0.4557
# Epoch 170/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6068 - acc: 0.6517 - val_loss: 0.8313 - val_acc: 0.4557
# Epoch 171/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.6005 - acc: 0.6667 - val_loss: 0.8295 - val_acc: 0.4557
# Epoch 172/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5958 - acc: 0.6486 - val_loss: 0.8299 - val_acc: 0.4557
# Epoch 173/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5959 - acc: 0.6817 - val_loss: 0.8296 - val_acc: 0.4557
# Epoch 174/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5949 - acc: 0.6727 - val_loss: 0.8302 - val_acc: 0.4430
# Epoch 175/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5950 - acc: 0.6817 - val_loss: 0.8318 - val_acc: 0.4430
# Epoch 176/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5833 - acc: 0.6907 - val_loss: 0.8309 - val_acc: 0.4430
# Epoch 177/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5994 - acc: 0.6937 - val_loss: 0.8309 - val_acc: 0.4430
# Epoch 178/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5934 - acc: 0.6757 - val_loss: 0.8312 - val_acc: 0.4557
# Epoch 179/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5929 - acc: 0.6757 - val_loss: 0.8311 - val_acc: 0.4557
# Epoch 180/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.6024 - acc: 0.6456 - val_loss: 0.8332 - val_acc: 0.4430
# Epoch 181/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.6101 - acc: 0.6607 - val_loss: 0.8325 - val_acc: 0.4430
# Epoch 182/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5907 - acc: 0.6847 - val_loss: 0.8345 - val_acc: 0.4430
# Epoch 183/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5949 - acc: 0.6877 - val_loss: 0.8354 - val_acc: 0.4430
# Epoch 184/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5912 - acc: 0.6667 - val_loss: 0.8361 - val_acc: 0.4430
# Epoch 185/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5940 - acc: 0.6607 - val_loss: 0.8386 - val_acc: 0.4304
# Epoch 186/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5942 - acc: 0.6607 - val_loss: 0.8378 - val_acc: 0.4304
# Epoch 187/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5925 - acc: 0.6907 - val_loss: 0.8371 - val_acc: 0.4304
# Epoch 188/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5874 - acc: 0.6907 - val_loss: 0.8387 - val_acc: 0.4304
# Epoch 189/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5891 - acc: 0.6847 - val_loss: 0.8401 - val_acc: 0.4304
# Epoch 190/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5934 - acc: 0.6757 - val_loss: 0.8407 - val_acc: 0.4304
# Epoch 191/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5865 - acc: 0.6877 - val_loss: 0.8409 - val_acc: 0.4304
# Epoch 192/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5883 - acc: 0.6577 - val_loss: 0.8407 - val_acc: 0.4304
# Epoch 193/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5787 - acc: 0.6907 - val_loss: 0.8406 - val_acc: 0.4304
# Epoch 194/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5852 - acc: 0.6907 - val_loss: 0.8386 - val_acc: 0.4430
# Epoch 195/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5851 - acc: 0.6877 - val_loss: 0.8380 - val_acc: 0.4430
# Epoch 196/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5803 - acc: 0.7057 - val_loss: 0.8362 - val_acc: 0.4430
# Epoch 197/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5824 - acc: 0.6787 - val_loss: 0.8341 - val_acc: 0.4430
# Epoch 198/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5925 - acc: 0.6637 - val_loss: 0.8310 - val_acc: 0.4430
# Epoch 199/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5814 - acc: 0.6907 - val_loss: 0.8289 - val_acc: 0.4557
# Epoch 200/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5837 - acc: 0.6817 - val_loss: 0.8267 - val_acc: 0.4557
# Epoch 201/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5837 - acc: 0.6757 - val_loss: 0.8260 - val_acc: 0.4557
# Epoch 202/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5812 - acc: 0.7027 - val_loss: 0.8282 - val_acc: 0.4557
# Epoch 203/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5757 - acc: 0.7027 - val_loss: 0.8280 - val_acc: 0.4557
# Epoch 204/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5737 - acc: 0.6937 - val_loss: 0.8284 - val_acc: 0.4557
# Epoch 205/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5813 - acc: 0.6997 - val_loss: 0.8290 - val_acc: 0.4430
# Epoch 206/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5739 - acc: 0.6847 - val_loss: 0.8287 - val_acc: 0.4557
# Epoch 207/500
# 333/333 [==============================] - 11s 32ms/step - loss: 0.5773 - acc: 0.7057 - val_loss: 0.8275 - val_acc: 0.4557
# Epoch 208/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.5746 - acc: 0.7027 - val_loss: 0.8249 - val_acc: 0.4557
# Epoch 209/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5706 - acc: 0.6937 - val_loss: 0.8229 - val_acc: 0.4557
# Epoch 210/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5691 - acc: 0.7027 - val_loss: 0.8223 - val_acc: 0.4557
# Epoch 211/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5676 - acc: 0.6967 - val_loss: 0.8206 - val_acc: 0.4557
# Epoch 212/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5750 - acc: 0.6817 - val_loss: 0.8197 - val_acc: 0.4557
# Epoch 213/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5697 - acc: 0.7177 - val_loss: 0.8209 - val_acc: 0.4557
# Epoch 214/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5750 - acc: 0.7027 - val_loss: 0.8213 - val_acc: 0.4810
# Epoch 215/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5641 - acc: 0.6877 - val_loss: 0.8221 - val_acc: 0.4810
# Epoch 216/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5581 - acc: 0.7117 - val_loss: 0.8227 - val_acc: 0.4810
# Epoch 217/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5657 - acc: 0.7057 - val_loss: 0.8199 - val_acc: 0.4810
# Epoch 218/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5762 - acc: 0.6817 - val_loss: 0.8179 - val_acc: 0.4810
# Epoch 219/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5740 - acc: 0.7267 - val_loss: 0.8168 - val_acc: 0.4937
# Epoch 220/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5818 - acc: 0.6847 - val_loss: 0.8143 - val_acc: 0.4937
# Epoch 221/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5598 - acc: 0.7147 - val_loss: 0.8113 - val_acc: 0.5063
# Epoch 222/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5725 - acc: 0.6967 - val_loss: 0.8091 - val_acc: 0.5063
# Epoch 223/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5702 - acc: 0.6907 - val_loss: 0.8082 - val_acc: 0.5063
# Epoch 224/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5622 - acc: 0.6997 - val_loss: 0.8066 - val_acc: 0.5063
# Epoch 225/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5702 - acc: 0.6997 - val_loss: 0.8049 - val_acc: 0.5063
# Epoch 226/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5638 - acc: 0.7027 - val_loss: 0.8034 - val_acc: 0.5063
# Epoch 227/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5681 - acc: 0.6817 - val_loss: 0.8036 - val_acc: 0.5063
# Epoch 228/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5687 - acc: 0.7027 - val_loss: 0.8008 - val_acc: 0.5063
# Epoch 229/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5619 - acc: 0.7177 - val_loss: 0.7991 - val_acc: 0.5063
# Epoch 230/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.5734 - acc: 0.6907 - val_loss: 0.7958 - val_acc: 0.5063
# Epoch 231/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.5625 - acc: 0.7057 - val_loss: 0.7932 - val_acc: 0.5063
# Epoch 232/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5680 - acc: 0.6937 - val_loss: 0.7919 - val_acc: 0.5190
# Epoch 233/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5600 - acc: 0.7057 - val_loss: 0.7902 - val_acc: 0.5190
# Epoch 234/500
# 333/333 [==============================] - 11s 33ms/step - loss: 0.5518 - acc: 0.7237 - val_loss: 0.7886 - val_acc: 0.5190
# Epoch 235/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5651 - acc: 0.6967 - val_loss: 0.7876 - val_acc: 0.5190
# Epoch 236/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5740 - acc: 0.6877 - val_loss: 0.7876 - val_acc: 0.5190
# Epoch 237/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5607 - acc: 0.7057 - val_loss: 0.7869 - val_acc: 0.5190
# Epoch 238/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5571 - acc: 0.7087 - val_loss: 0.7855 - val_acc: 0.5190
# Epoch 239/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5632 - acc: 0.6997 - val_loss: 0.7828 - val_acc: 0.5190
# Epoch 240/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5645 - acc: 0.7087 - val_loss: 0.7802 - val_acc: 0.5316
# Epoch 241/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5546 - acc: 0.7177 - val_loss: 0.7792 - val_acc: 0.5316
# Epoch 242/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5513 - acc: 0.7147 - val_loss: 0.7777 - val_acc: 0.5316
# Epoch 243/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5566 - acc: 0.6937 - val_loss: 0.7763 - val_acc: 0.5443
# Epoch 244/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5621 - acc: 0.7087 - val_loss: 0.7756 - val_acc: 0.5443
# Epoch 245/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5599 - acc: 0.7117 - val_loss: 0.7751 - val_acc: 0.5443
# Epoch 246/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5588 - acc: 0.6877 - val_loss: 0.7751 - val_acc: 0.5443
# Epoch 247/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5541 - acc: 0.7207 - val_loss: 0.7748 - val_acc: 0.5443
# Epoch 248/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.5452 - acc: 0.7327 - val_loss: 0.7760 - val_acc: 0.5316
# Epoch 249/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5625 - acc: 0.7147 - val_loss: 0.7755 - val_acc: 0.5316
# Epoch 250/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5546 - acc: 0.7147 - val_loss: 0.7740 - val_acc: 0.5316
# Epoch 251/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5530 - acc: 0.7147 - val_loss: 0.7733 - val_acc: 0.5316
# Epoch 252/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5490 - acc: 0.7177 - val_loss: 0.7717 - val_acc: 0.5316
# Epoch 253/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5497 - acc: 0.7177 - val_loss: 0.7699 - val_acc: 0.5316
# Epoch 254/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5418 - acc: 0.7087 - val_loss: 0.7689 - val_acc: 0.5316
# Epoch 255/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5499 - acc: 0.7087 - val_loss: 0.7681 - val_acc: 0.5316
# Epoch 256/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5504 - acc: 0.7207 - val_loss: 0.7666 - val_acc: 0.5316
# Epoch 257/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5462 - acc: 0.7087 - val_loss: 0.7656 - val_acc: 0.5316
# Epoch 258/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5565 - acc: 0.6817 - val_loss: 0.7635 - val_acc: 0.5316
# Epoch 259/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.5565 - acc: 0.7237 - val_loss: 0.7627 - val_acc: 0.5316
# Epoch 260/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5498 - acc: 0.7057 - val_loss: 0.7601 - val_acc: 0.5316
# Epoch 261/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5539 - acc: 0.7237 - val_loss: 0.7583 - val_acc: 0.5316
# Epoch 262/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5430 - acc: 0.7237 - val_loss: 0.7574 - val_acc: 0.5316
# Epoch 263/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5415 - acc: 0.7237 - val_loss: 0.7576 - val_acc: 0.5316
# Epoch 264/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5344 - acc: 0.7327 - val_loss: 0.7557 - val_acc: 0.5316
# Epoch 265/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5404 - acc: 0.7417 - val_loss: 0.7538 - val_acc: 0.5316
# Epoch 266/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5420 - acc: 0.7327 - val_loss: 0.7529 - val_acc: 0.5316
# Epoch 267/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5420 - acc: 0.7297 - val_loss: 0.7514 - val_acc: 0.5316
# Epoch 268/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5445 - acc: 0.7087 - val_loss: 0.7491 - val_acc: 0.5443
# Epoch 269/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5405 - acc: 0.7087 - val_loss: 0.7475 - val_acc: 0.5443
# Epoch 270/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5359 - acc: 0.7267 - val_loss: 0.7449 - val_acc: 0.5443
# Epoch 271/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5393 - acc: 0.7207 - val_loss: 0.7421 - val_acc: 0.5570
# Epoch 272/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5391 - acc: 0.7177 - val_loss: 0.7410 - val_acc: 0.5570
# Epoch 273/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5323 - acc: 0.7357 - val_loss: 0.7395 - val_acc: 0.5570
# Epoch 274/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5361 - acc: 0.7327 - val_loss: 0.7387 - val_acc: 0.5570
# Epoch 275/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5399 - acc: 0.7447 - val_loss: 0.7361 - val_acc: 0.5570
# Epoch 276/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5364 - acc: 0.7447 - val_loss: 0.7356 - val_acc: 0.5570
# Epoch 277/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5442 - acc: 0.7117 - val_loss: 0.7338 - val_acc: 0.5570
# Epoch 278/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5355 - acc: 0.7357 - val_loss: 0.7322 - val_acc: 0.5570
# Epoch 279/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.5339 - acc: 0.7417 - val_loss: 0.7299 - val_acc: 0.5570
# Epoch 280/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5398 - acc: 0.7357 - val_loss: 0.7295 - val_acc: 0.5570
# Epoch 281/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5254 - acc: 0.7387 - val_loss: 0.7269 - val_acc: 0.5570
# Epoch 282/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5420 - acc: 0.7207 - val_loss: 0.7243 - val_acc: 0.5696
# Epoch 283/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5248 - acc: 0.7508 - val_loss: 0.7217 - val_acc: 0.5823
# Epoch 284/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5322 - acc: 0.7267 - val_loss: 0.7196 - val_acc: 0.5823
# Epoch 285/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5328 - acc: 0.7447 - val_loss: 0.7189 - val_acc: 0.5823
# Epoch 286/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5260 - acc: 0.7417 - val_loss: 0.7184 - val_acc: 0.5696
# Epoch 287/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5310 - acc: 0.7568 - val_loss: 0.7174 - val_acc: 0.5696
# Epoch 288/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.5269 - acc: 0.7387 - val_loss: 0.7165 - val_acc: 0.5696
# Epoch 289/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5273 - acc: 0.7297 - val_loss: 0.7142 - val_acc: 0.5696
# Epoch 290/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5321 - acc: 0.7327 - val_loss: 0.7131 - val_acc: 0.5570
# Epoch 291/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5318 - acc: 0.7568 - val_loss: 0.7121 - val_acc: 0.5570
# Epoch 292/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5239 - acc: 0.7327 - val_loss: 0.7106 - val_acc: 0.5570
# Epoch 293/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5286 - acc: 0.7297 - val_loss: 0.7092 - val_acc: 0.5570
# Epoch 294/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5343 - acc: 0.7207 - val_loss: 0.7086 - val_acc: 0.5570
# Epoch 295/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5235 - acc: 0.7568 - val_loss: 0.7078 - val_acc: 0.5570
# Epoch 296/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5252 - acc: 0.7447 - val_loss: 0.7059 - val_acc: 0.5570
# Epoch 297/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5260 - acc: 0.7357 - val_loss: 0.7034 - val_acc: 0.5570
# Epoch 298/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5246 - acc: 0.7387 - val_loss: 0.7006 - val_acc: 0.5570
# Epoch 299/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5202 - acc: 0.7357 - val_loss: 0.6985 - val_acc: 0.5443
# Epoch 300/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5164 - acc: 0.7538 - val_loss: 0.6970 - val_acc: 0.5443
# Epoch 301/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5180 - acc: 0.7447 - val_loss: 0.6956 - val_acc: 0.5443
# Epoch 302/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5132 - acc: 0.7477 - val_loss: 0.6928 - val_acc: 0.5443
# Epoch 303/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5223 - acc: 0.7508 - val_loss: 0.6906 - val_acc: 0.5443
# Epoch 304/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5181 - acc: 0.7387 - val_loss: 0.6891 - val_acc: 0.5316
# Epoch 305/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5172 - acc: 0.7297 - val_loss: 0.6878 - val_acc: 0.5443
# Epoch 306/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5179 - acc: 0.7538 - val_loss: 0.6865 - val_acc: 0.5570
# Epoch 307/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5131 - acc: 0.7447 - val_loss: 0.6854 - val_acc: 0.5443
# Epoch 308/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5119 - acc: 0.7417 - val_loss: 0.6843 - val_acc: 0.5570
# Epoch 309/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5146 - acc: 0.7477 - val_loss: 0.6826 - val_acc: 0.5570
# Epoch 310/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.5126 - acc: 0.7628 - val_loss: 0.6812 - val_acc: 0.5823
# Epoch 311/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5122 - acc: 0.7538 - val_loss: 0.6800 - val_acc: 0.5696
# Epoch 312/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5098 - acc: 0.7628 - val_loss: 0.6790 - val_acc: 0.5696
# Epoch 313/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5140 - acc: 0.7718 - val_loss: 0.6774 - val_acc: 0.5696
# Epoch 314/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5011 - acc: 0.7568 - val_loss: 0.6753 - val_acc: 0.5696
# Epoch 315/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5187 - acc: 0.7477 - val_loss: 0.6739 - val_acc: 0.5696
# Epoch 316/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5022 - acc: 0.7538 - val_loss: 0.6718 - val_acc: 0.5696
# Epoch 317/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.5135 - acc: 0.7417 - val_loss: 0.6704 - val_acc: 0.5823
# Epoch 318/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.5106 - acc: 0.7387 - val_loss: 0.6689 - val_acc: 0.5949
# Epoch 319/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5074 - acc: 0.7568 - val_loss: 0.6681 - val_acc: 0.5949
# Epoch 320/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5049 - acc: 0.7658 - val_loss: 0.6673 - val_acc: 0.5949
# Epoch 321/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.5000 - acc: 0.7838 - val_loss: 0.6667 - val_acc: 0.5949
# Epoch 322/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.5154 - acc: 0.7387 - val_loss: 0.6654 - val_acc: 0.5949
# Epoch 323/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5054 - acc: 0.7477 - val_loss: 0.6633 - val_acc: 0.5949
# Epoch 324/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5109 - acc: 0.7628 - val_loss: 0.6616 - val_acc: 0.5949
# Epoch 325/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5014 - acc: 0.7718 - val_loss: 0.6602 - val_acc: 0.5949
# Epoch 326/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.5045 - acc: 0.7538 - val_loss: 0.6586 - val_acc: 0.5949
# Epoch 327/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4912 - acc: 0.7508 - val_loss: 0.6577 - val_acc: 0.5949
# Epoch 328/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5120 - acc: 0.7447 - val_loss: 0.6572 - val_acc: 0.5949
# Epoch 329/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5032 - acc: 0.7718 - val_loss: 0.6565 - val_acc: 0.5949
# Epoch 330/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5027 - acc: 0.7658 - val_loss: 0.6559 - val_acc: 0.5949
# Epoch 331/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.5029 - acc: 0.7748 - val_loss: 0.6553 - val_acc: 0.5949
# Epoch 332/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4969 - acc: 0.7598 - val_loss: 0.6548 - val_acc: 0.5949
# Epoch 333/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4969 - acc: 0.7598 - val_loss: 0.6546 - val_acc: 0.5949
# Epoch 334/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4966 - acc: 0.7688 - val_loss: 0.6538 - val_acc: 0.5949
# Epoch 335/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4988 - acc: 0.7658 - val_loss: 0.6539 - val_acc: 0.6076
# Epoch 336/500
# 333/333 [==============================] - 7s 23ms/step - loss: 0.4973 - acc: 0.7628 - val_loss: 0.6534 - val_acc: 0.6076
# Epoch 337/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4962 - acc: 0.7868 - val_loss: 0.6526 - val_acc: 0.6076
# Epoch 338/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5026 - acc: 0.7598 - val_loss: 0.6522 - val_acc: 0.6076
# Epoch 339/500
# 333/333 [==============================] - 7s 23ms/step - loss: 0.4974 - acc: 0.7628 - val_loss: 0.6518 - val_acc: 0.6076
# Epoch 340/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5060 - acc: 0.7568 - val_loss: 0.6515 - val_acc: 0.6076
# Epoch 341/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.5005 - acc: 0.7658 - val_loss: 0.6509 - val_acc: 0.6076
# Epoch 342/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4954 - acc: 0.7568 - val_loss: 0.6500 - val_acc: 0.6203
# Epoch 343/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4936 - acc: 0.7538 - val_loss: 0.6490 - val_acc: 0.6203
# Epoch 344/500
# 333/333 [==============================] - 7s 23ms/step - loss: 0.4964 - acc: 0.7477 - val_loss: 0.6477 - val_acc: 0.6203
# Epoch 345/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.5048 - acc: 0.7568 - val_loss: 0.6467 - val_acc: 0.6203
# Epoch 346/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4925 - acc: 0.7538 - val_loss: 0.6462 - val_acc: 0.6076
# Epoch 347/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4992 - acc: 0.7718 - val_loss: 0.6459 - val_acc: 0.6076
# Epoch 348/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.5003 - acc: 0.7568 - val_loss: 0.6456 - val_acc: 0.6203
# Epoch 349/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4959 - acc: 0.7688 - val_loss: 0.6455 - val_acc: 0.6203
# Epoch 350/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4977 - acc: 0.7628 - val_loss: 0.6453 - val_acc: 0.6203
# Epoch 351/500
# ...
# Epoch 384/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4753 - acc: 0.7748 - val_loss: 0.6242 - val_acc: 0.5949
# Epoch 385/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4789 - acc: 0.7748 - val_loss: 0.6230 - val_acc: 0.5949
# Epoch 386/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4774 - acc: 0.7868 - val_loss: 0.6222 - val_acc: 0.5949
# Epoch 387/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4767 - acc: 0.7898 - val_loss: 0.6220 - val_acc: 0.5949
# Epoch 388/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4792 - acc: 0.7658 - val_loss: 0.6217 - val_acc: 0.6076
# Epoch 389/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4742 - acc: 0.7868 - val_loss: 0.6217 - val_acc: 0.6076
# Epoch 390/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4808 - acc: 0.7718 - val_loss: 0.6211 - val_acc: 0.6203
# Epoch 391/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4894 - acc: 0.7538 - val_loss: 0.6210 - val_acc: 0.6203
# Epoch 392/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4815 - acc: 0.7838 - val_loss: 0.6206 - val_acc: 0.6203
# Epoch 393/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4718 - acc: 0.7718 - val_loss: 0.6197 - val_acc: 0.6203
# Epoch 394/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4776 - acc: 0.7778 - val_loss: 0.6195 - val_acc: 0.6582
# Epoch 395/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4710 - acc: 0.7778 - val_loss: 0.6191 - val_acc: 0.6582
# Epoch 396/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4730 - acc: 0.7748 - val_loss: 0.6185 - val_acc: 0.6582
# Epoch 397/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4731 - acc: 0.7868 - val_loss: 0.6180 - val_acc: 0.6456
# Epoch 398/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4665 - acc: 0.8018 - val_loss: 0.6171 - val_acc: 0.6203
# Epoch 399/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4684 - acc: 0.7958 - val_loss: 0.6165 - val_acc: 0.6076
# Epoch 400/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4710 - acc: 0.7958 - val_loss: 0.6161 - val_acc: 0.6329
# Epoch 401/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4774 - acc: 0.7898 - val_loss: 0.6159 - val_acc: 0.6076
# Epoch 402/500
# 333/333 [==============================] - 7s 23ms/step - loss: 0.4731 - acc: 0.7808 - val_loss: 0.6159 - val_acc: 0.6076
# Epoch 403/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4770 - acc: 0.7808 - val_loss: 0.6156 - val_acc: 0.6076
# Epoch 404/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4723 - acc: 0.7898 - val_loss: 0.6151 - val_acc: 0.6329
# Epoch 405/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4882 - acc: 0.7658 - val_loss: 0.6150 - val_acc: 0.6203
# Epoch 406/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4769 - acc: 0.7838 - val_loss: 0.6138 - val_acc: 0.6329
# Epoch 407/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4775 - acc: 0.7658 - val_loss: 0.6132 - val_acc: 0.6329
# Epoch 408/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4752 - acc: 0.7928 - val_loss: 0.6131 - val_acc: 0.6329
# Epoch 409/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4806 - acc: 0.8048 - val_loss: 0.6130 - val_acc: 0.6329
# Epoch 410/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4751 - acc: 0.7868 - val_loss: 0.6134 - val_acc: 0.6203
# Epoch 411/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4809 - acc: 0.7718 - val_loss: 0.6132 - val_acc: 0.6203
# Epoch 412/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4721 - acc: 0.7778 - val_loss: 0.6133 - val_acc: 0.6329
# Epoch 413/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4694 - acc: 0.7838 - val_loss: 0.6136 - val_acc: 0.6329
# Epoch 414/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4704 - acc: 0.7898 - val_loss: 0.6140 - val_acc: 0.6329
# Epoch 415/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4708 - acc: 0.7838 - val_loss: 0.6138 - val_acc: 0.6329
# Epoch 416/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4766 - acc: 0.7868 - val_loss: 0.6141 - val_acc: 0.6203
# Epoch 417/500
# 333/333 [==============================] - 7s 21ms/step - loss: 0.4664 - acc: 0.7958 - val_loss: 0.6145 - val_acc: 0.6203
# Epoch 418/500
# 333/333 [==============================] - 7s 21ms/step - loss: 0.4659 - acc: 0.8048 - val_loss: 0.6149 - val_acc: 0.6203
# Epoch 419/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4735 - acc: 0.7628 - val_loss: 0.6153 - val_acc: 0.6203
# Epoch 420/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4616 - acc: 0.8048 - val_loss: 0.6155 - val_acc: 0.6203
# Epoch 421/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4718 - acc: 0.7928 - val_loss: 0.6154 - val_acc: 0.6203
# Epoch 422/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4582 - acc: 0.7988 - val_loss: 0.6156 - val_acc: 0.6203
# Epoch 423/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4706 - acc: 0.7898 - val_loss: 0.6156 - val_acc: 0.6456
# Epoch 424/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4734 - acc: 0.7778 - val_loss: 0.6151 - val_acc: 0.6329
# Epoch 425/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4644 - acc: 0.7928 - val_loss: 0.6147 - val_acc: 0.6329
# Epoch 426/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4787 - acc: 0.7898 - val_loss: 0.6144 - val_acc: 0.6329
# Epoch 427/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4668 - acc: 0.7928 - val_loss: 0.6144 - val_acc: 0.6456
# Epoch 428/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4649 - acc: 0.7988 - val_loss: 0.6144 - val_acc: 0.6329
# Epoch 429/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4678 - acc: 0.7868 - val_loss: 0.6142 - val_acc: 0.6329
# Epoch 430/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4592 - acc: 0.7928 - val_loss: 0.6144 - val_acc: 0.6329
# Epoch 431/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4674 - acc: 0.7808 - val_loss: 0.6139 - val_acc: 0.6203
# Epoch 432/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4642 - acc: 0.7928 - val_loss: 0.6135 - val_acc: 0.6203
# Epoch 433/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4645 - acc: 0.7898 - val_loss: 0.6133 - val_acc: 0.6203
# Epoch 434/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4648 - acc: 0.7898 - val_loss: 0.6129 - val_acc: 0.6203
# Epoch 435/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4652 - acc: 0.7778 - val_loss: 0.6132 - val_acc: 0.6203
# Epoch 436/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4655 - acc: 0.7958 - val_loss: 0.6129 - val_acc: 0.6329
# Epoch 437/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4683 - acc: 0.7958 - val_loss: 0.6123 - val_acc: 0.6329
# Epoch 438/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4605 - acc: 0.7898 - val_loss: 0.6120 - val_acc: 0.6203
# Epoch 439/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4738 - acc: 0.7898 - val_loss: 0.6119 - val_acc: 0.6203
# Epoch 440/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4608 - acc: 0.7928 - val_loss: 0.6116 - val_acc: 0.6203
# Epoch 441/500
# 333/333 [==============================] - 150s 452ms/step - loss: 0.4571 - acc: 0.7898 - val_loss: 0.6114 - val_acc: 0.6203
# Epoch 442/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.4683 - acc: 0.7838 - val_loss: 0.6114 - val_acc: 0.6203
# Epoch 443/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4662 - acc: 0.7868 - val_loss: 0.6113 - val_acc: 0.6329
# Epoch 444/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.4563 - acc: 0.7958 - val_loss: 0.6113 - val_acc: 0.6456
# Epoch 445/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4597 - acc: 0.7958 - val_loss: 0.6113 - val_acc: 0.6456
# Epoch 446/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4541 - acc: 0.8108 - val_loss: 0.6115 - val_acc: 0.6456
# Epoch 447/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4542 - acc: 0.8168 - val_loss: 0.6116 - val_acc: 0.6456
# Epoch 448/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4581 - acc: 0.7928 - val_loss: 0.6118 - val_acc: 0.6456
# Epoch 449/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4565 - acc: 0.8108 - val_loss: 0.6119 - val_acc: 0.6456
# Epoch 450/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4572 - acc: 0.8048 - val_loss: 0.6119 - val_acc: 0.6456
# Epoch 451/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4702 - acc: 0.8018 - val_loss: 0.6119 - val_acc: 0.6456
# Epoch 452/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4579 - acc: 0.7988 - val_loss: 0.6122 - val_acc: 0.6456
# Epoch 453/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4593 - acc: 0.8078 - val_loss: 0.6123 - val_acc: 0.6456
# Epoch 454/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4577 - acc: 0.8048 - val_loss: 0.6130 - val_acc: 0.6456
# Epoch 455/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4557 - acc: 0.8258 - val_loss: 0.6132 - val_acc: 0.6456
# Epoch 456/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4599 - acc: 0.7958 - val_loss: 0.6139 - val_acc: 0.6456
# Epoch 457/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4573 - acc: 0.7988 - val_loss: 0.6141 - val_acc: 0.6582
# Epoch 458/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4507 - acc: 0.8018 - val_loss: 0.6148 - val_acc: 0.6582
# Epoch 459/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4564 - acc: 0.8048 - val_loss: 0.6160 - val_acc: 0.6456
# Epoch 460/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4635 - acc: 0.7838 - val_loss: 0.6165 - val_acc: 0.6456
# Epoch 461/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4603 - acc: 0.8048 - val_loss: 0.6162 - val_acc: 0.6456
# Epoch 462/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4572 - acc: 0.7928 - val_loss: 0.6162 - val_acc: 0.6456
# Epoch 463/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4563 - acc: 0.7928 - val_loss: 0.6167 - val_acc: 0.6456
# Epoch 464/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4696 - acc: 0.7958 - val_loss: 0.6165 - val_acc: 0.6329
# Epoch 465/500
# 333/333 [==============================] - 8s 24ms/step - loss: 0.4558 - acc: 0.7958 - val_loss: 0.6169 - val_acc: 0.6456
# Epoch 466/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4557 - acc: 0.7988 - val_loss: 0.6177 - val_acc: 0.6456
# Epoch 467/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.4577 - acc: 0.7778 - val_loss: 0.6181 - val_acc: 0.6456
# Epoch 468/500
# 333/333 [==============================] - 11s 32ms/step - loss: 0.4532 - acc: 0.8168 - val_loss: 0.6185 - val_acc: 0.6456
# Epoch 469/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.4586 - acc: 0.7988 - val_loss: 0.6190 - val_acc: 0.6456
# Epoch 470/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.4518 - acc: 0.8018 - val_loss: 0.6199 - val_acc: 0.6456
# Epoch 471/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4621 - acc: 0.7868 - val_loss: 0.6201 - val_acc: 0.6456
# Epoch 472/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4558 - acc: 0.7928 - val_loss: 0.6195 - val_acc: 0.6456
# Epoch 473/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4539 - acc: 0.8138 - val_loss: 0.6197 - val_acc: 0.6456
# Epoch 474/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4539 - acc: 0.8198 - val_loss: 0.6197 - val_acc: 0.6456
# Epoch 475/500
# 333/333 [==============================] - 7s 22ms/step - loss: 0.4616 - acc: 0.7988 - val_loss: 0.6195 - val_acc: 0.6456
# Epoch 476/500
# 333/333 [==============================] - 8s 23ms/step - loss: 0.4592 - acc: 0.8018 - val_loss: 0.6194 - val_acc: 0.6329
# Epoch 477/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4552 - acc: 0.8048 - val_loss: 0.6184 - val_acc: 0.6456
# Epoch 478/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4475 - acc: 0.8048 - val_loss: 0.6175 - val_acc: 0.6456
# Epoch 479/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.4505 - acc: 0.8078 - val_loss: 0.6169 - val_acc: 0.6456
# Epoch 480/500
# 333/333 [==============================] - 8s 25ms/step - loss: 0.4477 - acc: 0.8078 - val_loss: 0.6165 - val_acc: 0.6329
# Epoch 481/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.4528 - acc: 0.8108 - val_loss: 0.6165 - val_acc: 0.6329
# Epoch 482/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.4602 - acc: 0.8048 - val_loss: 0.6163 - val_acc: 0.6203
# Epoch 483/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.4617 - acc: 0.7958 - val_loss: 0.6153 - val_acc: 0.6329
# Epoch 484/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.4592 - acc: 0.7958 - val_loss: 0.6156 - val_acc: 0.6329
# Epoch 485/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.4523 - acc: 0.8168 - val_loss: 0.6160 - val_acc: 0.6329
# Epoch 486/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.4570 - acc: 0.7838 - val_loss: 0.6156 - val_acc: 0.6329
# Epoch 487/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.4519 - acc: 0.8108 - val_loss: 0.6157 - val_acc: 0.6329
# Epoch 488/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.4466 - acc: 0.8018 - val_loss: 0.6150 - val_acc: 0.6329
# Epoch 489/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.4543 - acc: 0.7988 - val_loss: 0.6155 - val_acc: 0.6203
# Epoch 490/500
# 333/333 [==============================] - 9s 28ms/step - loss: 0.4502 - acc: 0.8078 - val_loss: 0.6162 - val_acc: 0.6203
# Epoch 491/500
# 333/333 [==============================] - 10s 30ms/step - loss: 0.4437 - acc: 0.8138 - val_loss: 0.6182 - val_acc: 0.6329
# Epoch 492/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.4545 - acc: 0.7808 - val_loss: 0.6193 - val_acc: 0.6329
# Epoch 493/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.4504 - acc: 0.8048 - val_loss: 0.6189 - val_acc: 0.6329
# Epoch 494/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.4462 - acc: 0.8018 - val_loss: 0.6184 - val_acc: 0.6203
# Epoch 495/500
# 333/333 [==============================] - 11s 33ms/step - loss: 0.4498 - acc: 0.8018 - val_loss: 0.6182 - val_acc: 0.6203
# Epoch 496/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.4421 - acc: 0.8108 - val_loss: 0.6182 - val_acc: 0.6329
# Epoch 497/500
# 333/333 [==============================] - 10s 31ms/step - loss: 0.4438 - acc: 0.8108 - val_loss: 0.6180 - val_acc: 0.6329
# Epoch 498/500
# 333/333 [==============================] - 10s 29ms/step - loss: 0.4413 - acc: 0.8078 - val_loss: 0.6171 - val_acc: 0.6329
# Epoch 499/500
# 333/333 [==============================] - 9s 27ms/step - loss: 0.4547 - acc: 0.8138 - val_loss: 0.6161 - val_acc: 0.6329
# Epoch 500/500
# 333/333 [==============================] - 9s 26ms/step - loss: 0.4421 - acc: 0.8228 - val_loss: 0.6152 - val_acc: 0.6329

# %% [markdown]
# ### Step 6: Plot the training history
# We can view the training history of the model by plotting the performance (value of the loss function) for training and validation data in each epoch.

# %%
##### Step 6: plot train and validation loss #####
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Step 7: Evaluate the performance using test data
# We now use the test data, which has not been touched so far, to evaluate the performance of the final model. We will draw a Receiver Operator Characteristic(ROC) Curve and use Area Under the Curve (AUC) to measure performance.

# %%
##### Step 7: test the final model #####

# load final model
final_model = load_model('Data/Final_weights.hdf5')

# generate ROC and AUC
y_scores = final_model.predict([x_test])
fpr, tpr, _ = roc_curve(y_test, y_scores)
roc_auc = auc(fpr, tpr)

# plot ROC curve
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC = {0:.2f}'.format(roc_auc))
plt.show()

# Plot predicted Probability of CMV infection
pred = pd.DataFrame({"Probability":y_scores[:,0], "CMV":(y_test==1.0)})
sns.stripplot(y = "Probability", x = "CMV",data=pred);
sns.boxplot(y = "Probability", x = "CMV",data=pred);
# Out:
# WARNING:tensorflow:From /Users/zichenghu/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /Users/zichenghu/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %% [markdown]
# ### Step 8: Identify cells activated in the convolutional layers using a decision tree
# The internal nodes in the convolutional layers have one-to-one correspondence with cells in CyTOF data. Because of this, we can discover cells associated with the CMV infection by identifying nodes with high activation values. As an example, we will first build a decision tree model to identify highly activated nodes in filter 1 of convolutional layer 2. We then test the association between the identified cell subset and CMV infection. We choose to use a decision tree model because it is highly interpretable and is structurally similar to hieratical gating.

# %%
##### Step 8: Identify cells associated with CMV using a decistion tree #####

# extract activation value in filter 1 convolutional layer 2
get_activation = K.function([final_model.layers[0].input],
                                  [final_model.layers[6].output])
activation_value = get_activation([x_test])[0]
activation_value = activation_value[:,:,:,0]
activation_value = activation_value.reshape(activation_value.shape[0]*activation_value.shape[1])

# build the decision tree
x_test2 = x_test.reshape((x_test.shape[0]*x_test.shape[1],27))
 
regr_1 = DecisionTreeRegressor(max_depth=3)
regr_1.fit(x_test2, activation_value)

# plot the decision tree
dot_data = StringIO()
export_graphviz(regr_1, out_file=dot_data, 
                feature_names= markerNames,
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ### Step 9: Test the association between CMV and CD8+ CD94+ CD3+ cells
# The decision tree identified a CD8+ CD94+ CD3+ cell population to be highly activated. To see if this cell population is associated with CMV infection, we first quantify the proportion of CD8+ CD94+ CD3+ cell in each subject, and compare the proportions in CMV+ and CMV- populations.

# %%
##### plot association between CMV and CD8+ CD94+ CD3+ cell and CMV infection #####

# Identify the leaf that have the highest activation value
pred = regr_1.predict(X=x_test2)
leaf = regr_1.apply(x_test2)
max_leaf = [leaf[np.argmax(pred)]]

# quantify the proportion of CD8+ CD94+ CD3+ population
leaf = np.isin(leaf,max_leaf)
leaf = leaf.reshape(x_test.shape[0],x_test.shape[1])
leaf = np.mean(leaf, 1)
proportion_CMV = pd.DataFrame({"proportion":leaf,"CMV":y_test})

# plot the proportion of CD8+ CD94+ CD3+ cells
sns.boxplot(x="CMV", y="proportion", data=leaf_CMV)
plt.show()

# test the difference between CMV+ and CMV- population
test1 = ttest_ind(proportion_CMV.proportion[leaf_CMV.CMV==1],
          proportion_CMV.proportion[leaf_CMV.CMV==0], 
          equal_var = False)
print("P value = ", test1[1])
# Out:
# /Users/zichenghu/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# P value =  0.00275819644694

# %% [markdown]
# ### Conclusion
# In this tutorial, we build a deep convolutional neural network (CNN) to analyze CyTOF data. The deep CNN model is able to diagnose latent CMV infection with high accuracy. In addition, we were able to interpret the convolutional layers using decision trees. We discovered that a CD3+ CD8+ CD94+ population is highly activated in filter 1 of the second convolutional layer. The population is significantly associated with CMV infection.
